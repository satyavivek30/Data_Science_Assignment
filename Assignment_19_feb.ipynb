# %% [markdown]
# ## Assignment 19 feb 2023

# %% [markdown]
# **Q1):**What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# **Solution:** Flask is s collection of modules that helps programmer to develop codes for web application. Framework are fully developed packages that make the web Development process easier, faster, scalable and relieable.
#
# **Advantage of Flask**
# 1. It is a lighttweight framenwork that offer hassle free development.
# 2. Provoide flexibility to the developer environment with their module or architecture.
# 3. It is suitable for a small projects.
# 4. API are coherent and neat.
# 5. Offer a built-in development server and fast degugger.
#
# **Disadvantage of Flask**
# 1. Not suitable for big application and projects.
# 2. Lack of database and ORM
# 3. It does not offers an in-built admin site for maintaining records for insertion, deletion and modification.
# 4. Complex maintenance for large application.
# 5. Liberary must be installed manually.

# %% [markdown]
# **Q2):** Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %% [markdown]
# **Solution:**

# %% [markdown]
# ![Screenshot 2023-06-03 235752.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Screenshot 2023-06-03 235822.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Q3):** What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# **Solution:** In flask the app routing is refers to define URl routes that map to specific function or view handlers in your application. \
# It determine how different URL's or path are handled and what action should be taken when a particule URL is accessed.

# %% [markdown]
# 1. Flask application handles different HTTP requests for various URLs.
# 2. It helps to define the URL structure of an application. And it also helps in creating meaningful URLs that reflect the structure and functionality of your application.
# 3. By app routes you can seperate different part of your application based on functionality.
# 4. It allow you to definer dynamic routes by using placeholder or variables in URL patterns.

# %% [markdown]
# **Q4):** Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details: \
# Company Name: ABC Corporation \
# Location: India \
# Contact Detail: 999-999-9999

# %% [markdown]
# **Solution:**
# ScreenShot of the Output of following code.
# ```
# from flask import Flask
# app = Flask(__name__)
#
# @app.route('/welcome')
# def welcome():
#     return "Welcome to ABC Corporation!"
#
# @app.route('/')
# def details():
#     return "Company Name : ABC Corporation Location : India Contact Details : 999-999-9999"
#
# if __name__ == ("__main__"):
#     app.run(host = '0.0.0.0')
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Q5):** What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the
# url_for() function.?

# %% [markdown]
# **Solution :**
# In Flask for URL building the **url_for()** is used to build URL. It generate for specific rout based on its endpoint name.
#
# **Example**

# %%
from flask import Flask , url_for

app = Flask(__name__)

@app.route('/')
def intro():
    return "Hello World"

@app.route('/user/<username>')
def user_info(username):
    return f'Welcome. {username}!'

if __name__ == '__main__':
    with app.test_request_context():
        index_url = url_for('intro')
        profile_url = url_for('user_info', username = "satya")

        print(index_url)
        print(profile_url)
# Out:
# /
# /user/satya
